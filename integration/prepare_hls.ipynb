# %%
import torch
import torch.nn as nn
import time
import os

# %% [markdown]
# ## Load model

# %%
class FCN(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(FCN, self).__init__()
        self.input_size = input_size
        self.l1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.l2 = nn.Linear(hidden_size, num_classes)
    
    def forward(self, x):
        out = self.l1(x)
        out = self.relu(out)
        out = self.l2(out) 
        return out

# %%
model = FCN(1,1,1)
model = torch.load('full_model.pth')
model
# Out:
# FCN(
#   (l1): Linear(in_features=36, out_features=20, bias=True)
#   (relu): ReLU()
#   (l2): Linear(in_features=20, out_features=5, bias=True)
# )

# %%
for weight in model.state_dict():
    print(weight)
# Out:
# l1.weight
# l1.bias
# l2.weight
# l2.bias

# %%
for key, val in model.state_dict().items():
    print(key, val.shape)
# Out:
# l1.weight torch.Size([20, 36])
# l1.bias torch.Size([20])
# l2.weight torch.Size([5, 20])
# l2.bias torch.Size([5])

# %% [markdown]
# ## Print weights for HLS

# %%
l1_weight = model.state_dict()['l1.weight'].tolist()
l2_weight = model.state_dict()['l2.weight'].tolist()
l1_bias = model.state_dict()['l1.bias'].tolist()
l2_bias = model.state_dict()['l2.bias'].tolist()

# %%
print("const float l1_bias[HIDDEN_SIZE] = {", end='')
biases = ''
for b in l1_bias:
    biases += str(b) + ', '
biases = biases[:-2] + '};'
print(biases)
# Out:
# const float l1_bias[HIDDEN_SIZE] = {0.07260576635599136, 0.2663082480430603, -0.35320067405700684, 0.26500728726387024, 0.08590759336948395, -0.3907392919063568, 0.13615305721759796, -0.5529122352600098, 0.6287691593170166, 0.10721774399280548, 0.02466747909784317, 0.8518648743629456, -0.04959215596318245, -0.04843122512102127, -0.6003413200378418, -0.1684667021036148, -0.009274917654693127, 0.6424950361251831, -0.16273681819438934, 0.23099926114082336};

# %%
print("const float l2_bias[NUM_CLASSES] = {", end='')
biases = ''
for b in l2_bias:
    biases += str(b) + ', '
biases = biases[:-2] + '};'
print(biases)
# Out:
# const float l2_bias[NUM_CLASSES] = {0.9476150870323181, -0.06746087223291397, -0.4606860876083374, -0.4210861027240753, 0.15140864253044128};

# %%
print("const float l1_weights[HIDDEN_SIZE][INPUT_SIZE] = {", end='')
weights = ''
for row in l1_weight:
    weights += '{'
    for cell in row:
        weights += str(cell) + ', '
    weights = weights[:-2] + '},\n'
weights = weights[:-2] + '};'
print(weights)
# Out:
# const float l1_weights[HIDDEN_SIZE][INPUT_SIZE] = {{0.017793796956539154, 0.0067334482446312904, 0.1723751425743103, -0.02333994023501873, -0.07630836963653564, -0.09063716232776642, 0.09040980786085129, -0.18284820020198822, 0.08473024517297745, 0.08516852557659149, -0.0866696760058403, -0.14805960655212402, -0.16540396213531494, -0.02581767924129963, -0.11177141219377518, -0.07134535908699036, -0.13314352929592133, -0.15574730932712555, -0.16199088096618652, -0.0019097545882686973, 0.12946054339408875, -0.1012590229511261, -0.07195274531841278, 0.05875340849161148, -0.042263198643922806, 0.09179727733135223, 0.11246266216039658, -0.11463310569524765, 0.08561989665031433, -0.012116599828004837, 0.05730132386088371, -0.03909002244472504, 0.10171392560005188, -0.14406642317771912, 0.026497645303606987, 0.12936124205589294},
# {-0.014365200884640217, 0.3485833406448364, 1.3608559370040894, -0.15878449380397797, 0.7325801849365234, 0.3468405604362488, -0.5683023929595947, 0.053137823939323425, -0.3556346595287323, -0.6672089695930481, -0.14475344121456146, -0.8115837574005127, -0.10520577430725098, -1.289834976196289, -1.8699185848236084, 1.0092570781707764, 1.232372760772705, 1.171006202697754, -0.12703514099121094, -0.16117005050182343, 0.024937082082033157, -0.00814257562160492, 0.05430733785033226, -0.009580068290233612, 0.02128625102341175, -0.11759988963603973, -0.29412105679512024, 0.0791725143790245, -0.0197697002440691, 0.05878950655460358, 0.21326926350593567, -0.1001860648393631, -0.1540718823671341, -0.04562360420823097, 0.07407323271036148, -0.2550392150878906},
# {0.0887792557477951, -0.051527444273233414, 1.6424731016159058, -0.12811371684074402, 0.19827082753181458, 0.032900191843509674, 0.5694513320922852, -1.0755085945129395, 0.07729308307170868, 0.497700035572052, 0.18279851973056793, 0.26287558674812317, -1.1063289642333984, -0.6982718706130981, -1.863542079925537, 0.20452174544334412, 0.5344436168670654, 0.30206596851348877, -0.004523149691522121, -0.08763352781534195, -0.2024092972278595, -0.1472284346818924, -0.08410809189081192, 0.048844292759895325, 0.07943791896104813, -0.008605221286416054, -0.10719282925128937, 0.13058114051818848, 0.007488983683288097, 0.12008717656135559, 0.0085880933329463, -0.14349636435508728, -0.03608817607164383, -0.1167011708021164, 0.012624101713299751, -0.132084459066391},
# {-0.12179984152317047, -0.18097981810569763, 0.4728652834892273, -0.2891707718372345, -0.16879354417324066, -0.4169197082519531, 0.3388555645942688, -0.29757803678512573, 0.06760256737470627, 0.3634266257286072, 0.07853473722934723, 0.38281571865081787, -1.169141173362732, 0.30427849292755127, -1.2290476560592651, -0.9336150884628296, -0.47609448432922363, -0.9182078242301941, 0.01484585739672184, -0.17213799059391022, -0.013309435918927193, 0.0659705176949501, -0.12821663916110992, -0.12861213088035583, -0.17430004477500916, -0.08325061202049255, -0.07321207225322723, -0.057249195873737335, -0.12001063674688339, -0.10258176177740097, 0.03325667977333069, -0.009172625839710236, -0.0208992101252079, 0.06595133990049362, 0.018143121153116226, -0.1639965921640396},
# {0.04371641203761101, 0.16478076577186584, -0.154091015458107, -0.14869335293769836, 0.1512851119041443, -0.07319160550832748, 0.15043234825134277, -0.11404091119766235, -0.0642690658569336, 0.09683305770158768, -0.1287381649017334, 0.12610319256782532, 0.06003064662218094, 0.1169624924659729, 0.0043063536286354065, 0.1024923250079155, -0.1254645735025406, -0.005832691211253405, -0.009103445336222649, 0.04319215565919876, 0.057202525436878204, -0.013283089734613895, 0.02931634709239006, 0.035008564591407776, -0.018329745158553123, 0.02564198710024357, 0.08789073675870895, -0.036162734031677246, 0.03413255512714386, 0.14366111159324646, -0.05644538253545761, 0.048493389040231705, -0.03134043142199516, 0.14293892681598663, -0.031972017139196396, -0.07921271026134491},
# {0.26665830612182617, -0.1683502197265625, -0.2859951853752136, 0.39098772406578064, -0.5265411138534546, 0.34979912638664246, 0.45346131920814514, -0.7161387205123901, -0.11095541715621948, 0.5248491168022156, -0.43006399273872375, 0.29027360677719116, 0.8288500905036926, 0.43767452239990234, 0.12385716289281845, -0.17253431677818298, -0.8018791675567627, -0.1929766684770584, -0.09100756794214249, -0.1367703378200531, 0.00319261965341866, 0.10730154812335968, -0.2762894332408905, 0.035064179450273514, 0.08917359262704849, -0.022586487233638763, 0.02451322041451931, 0.13156479597091675, -0.017684202641248703, -0.1132689043879509, -0.01368348952382803, 0.04871738702058792, -0.010741952806711197, 0.011604861356317997, 0.017685245722532272, 0.04131173714995384},
# {-0.03796537220478058, 0.005723714828491211, -0.1435052454471588, -0.06837376207113266, -0.1150941476225853, -0.03628404438495636, -0.15519015491008759, -0.14709946513175964, 0.009428977966308594, -0.13298797607421875, -0.01957063376903534, -0.09849715232849121, 0.07177114486694336, -0.10280601680278778, -0.11780931800603867, -0.0008767843246459961, 0.05211047828197479, 0.061997368931770325, -0.05350639671087265, 0.12544266879558563, 0.1457611471414566, -0.11834337562322617, 0.07272748649120331, 0.0318499356508255, -0.06892874091863632, -0.003006651997566223, 0.1616763025522232, -0.05464484542608261, -0.13035818934440613, 0.06118707358837128, -0.15974938869476318, 0.041055843234062195, -0.031121954321861267, 0.14330951869487762, 0.13933466374874115, -0.15531669557094574},
# {-0.10712268948554993, 0.09118583798408508, -0.6055068373680115, 0.05200274661183357, 0.43233224749565125, 0.2522660493850708, 0.22849678993225098, 0.729317843914032, 0.49316442012786865, 0.45668888092041016, 0.860980212688446, 0.6910276412963867, 0.30832841992378235, 0.2020423859357834, 0.62704998254776, 0.0888211652636528, 0.5812436938285828, 0.19345758855342865, -0.017822735011577606, -0.02461772970855236, -0.17126160860061646, -0.17319165170192719, -0.13731205463409424, 0.0976438820362091, -0.0355231799185276, 0.07445228844881058, -0.2667683959007263, 0.15176434814929962, -0.019454475492239, -0.10652891546487808, 0.11980286240577698, 0.07342517375946045, 0.8295010328292847, 0.0885893702507019, -0.03669016435742378, 0.26616722345352173},
# {-0.2894253134727478, -0.09218168258666992, -0.35820838809013367, 0.15870359539985657, 0.6960052251815796, 0.1585453897714615, -0.4429558217525482, 0.2529413104057312, -0.19522437453269958, -0.6575601696968079, -0.06931497156620026, -0.6525768041610718, 0.3273628056049347, -0.4232962727546692, -0.037766434252262115, 0.3728140890598297, 0.3285806179046631, 0.3705718219280243, 0.13883627951145172, -0.06673610210418701, 0.11701086163520813, -0.0312007088214159, 0.07087366282939911, 0.09906560927629471, -0.016812250018119812, -0.04242096468806267, -0.266935795545578, -0.0862293690443039, -0.162301704287529, 0.05332630127668381, -0.17360693216323853, -0.024351932108402252, 0.590911328792572, 0.06348396092653275, 0.033239156007766724, -0.22740459442138672},
# {-0.6546680331230164, 0.40334081649780273, -1.355156660079956, -0.46870145201683044, 0.0805397629737854, -0.2977977991104126, -0.17533379793167114, 1.5411791801452637, 0.7692691683769226, -0.05083414912223816, 0.7867463231086731, 0.14006763696670532, 0.4415389895439148, 0.75217604637146, 1.7129460573196411, 0.08499760925769806, 0.39229223132133484, -0.017761599272489548, 0.022974997758865356, -0.15778802335262299, 0.14257875084877014, 0.19214197993278503, -0.2491040825843811, -0.09141241759061813, 0.07488764077425003, 0.020708484575152397, 0.1671900898218155, 0.12470558285713196, -0.09098547697067261, 0.13285762071609497, 0.0317680649459362, -0.13410000503063202, 0.04471755027770996, 0.18927660584449768, 0.11837729066610336, 0.054366640746593475},
# {-0.06820911169052124, -0.09387011080980301, 0.7172015309333801, 0.08197086304426193, -0.2504945993423462, -0.024337038397789, 0.4061861038208008, -0.8435454368591309, -0.31070709228515625, 0.47298663854599, -0.5925877094268799, 0.09454760700464249, 0.1741088479757309, -0.008427449502050877, -1.047713279724121, -0.12038819491863251, -0.25593316555023193, -0.2844794690608978, 0.11565423011779785, -0.02809007838368416, -0.07300512492656708, -0.16909034550189972, 0.05524057149887085, -0.19974303245544434, 0.17840269207954407, 0.029817286878824234, -0.15043625235557556, -0.08390785753726959, 0.051024943590164185, 0.030896471813321114, -0.040176644921302795, 0.22896267473697662, -0.0007569543085992336, 0.15522077679634094, -0.07971066236495972, 0.08443629741668701},
# {-0.00033923782757483423, -0.16893146932125092, -0.6057788729667664, -0.08260311931371689, 0.020082633942365646, -0.009429659694433212, -1.0175288915634155, 0.012479218654334545, -0.6112284064292908, -0.9864939451217651, -0.7510636448860168, -1.273533821105957, 0.14011622965335846, 1.1740527043002658e-05, 0.4443517029285431, -0.36400172114372253, -0.757636308670044, -0.4938904941082001, -0.08790980279445648, 0.026168014854192734, -0.16323670744895935, -0.19816769659519196, 0.18969982862472534, -0.13369254767894745, 0.13002213835716248, -0.08095862716436386, -0.06274934858083725, 0.04364172741770744, 0.20358718931674957, -0.08692383766174316, 0.14711768925189972, 0.00957716628909111, 0.13439172506332397, 0.022560985758900642, 0.23428082466125488, -0.10883764177560806},
# {0.2115888148546219, -0.46349167823791504, -0.6530951857566833, 0.05203848332166672, -0.620698869228363, -0.2080574929714203, 0.2882038950920105, -0.9322643280029297, -0.24003252387046814, 0.6679168343544006, -0.4224875271320343, 0.2059425562620163, -0.46495482325553894, 0.9560611844062805, 0.42695900797843933, -0.9464192986488342, -1.0337318181991577, -1.1380789279937744, -0.030241839587688446, -0.06532221287488937, -0.09973978251218796, -0.04785260558128357, 0.08653517812490463, 0.07181099057197571, 0.07370002567768097, -0.09125759452581406, 0.110863596200943, -0.043298110365867615, -0.09390074014663696, 0.01855461671948433, -0.136307030916214, -0.013624133542180061, 0.35268670320510864, 0.07110714912414551, 0.18976189196109772, -0.04695864021778107},
# {0.05016935244202614, 0.04272283986210823, -0.83160001039505, 0.5535300970077515, 0.21541713178157806, 0.42649349570274353, -0.3646610975265503, 0.044073961675167084, -0.391266405582428, -0.3544754385948181, -0.19872255623340607, -0.4260154962539673, 1.3710492849349976, -0.15610307455062866, 1.0800907611846924, 0.6649170517921448, 0.1434514969587326, 0.6981334686279297, -0.015050427056849003, -0.14882954955101013, 0.019364507868885994, -0.05165465176105499, 0.05988265573978424, 0.16941429674625397, -0.15427128970623016, 0.02092350646853447, 0.04446868225932121, 0.1587025672197342, 0.05993024259805679, -0.0023361737839877605, -0.05951321870088577, 0.13481470942497253, -0.2213653326034546, 0.18669815361499786, 0.059330012649297714, 0.22551949322223663},
# {0.4552808403968811, -0.4381568729877472, -0.2541740834712982, 0.580520510673523, -0.45519301295280457, 0.2668491303920746, 0.3277032673358917, -0.9400147795677185, -0.34418678283691406, 0.38958096504211426, -0.4042486548423767, 0.4375413954257965, 0.6190765500068665, 0.2869439721107483, 0.13575918972492218, -0.09591493755578995, -0.7430558800697327, -0.3483414649963379, -0.03868476673960686, 0.04962408170104027, -0.007808834780007601, 0.26013949513435364, -0.1442880630493164, 0.11073999851942062, -0.04287879914045334, -0.05390923097729683, 0.16129758954048157, -0.035126328468322754, -0.025970812886953354, 0.13339222967624664, 0.08462484925985336, -0.07264307141304016, -0.04831263795495033, 0.10906466841697693, -0.2395273894071579, -0.009863287210464478},
# {0.2720407247543335, -0.3797333240509033, 0.28248828649520874, 0.29110994935035706, -0.4480282664299011, 0.0738036260008812, 0.5356168746948242, -1.348799467086792, -0.0862860307097435, 0.9512116312980652, -0.49670252203941345, 0.5885409712791443, -0.4836246073246002, 0.3323947787284851, -0.6395453214645386, -0.5866990685462952, -0.9416025876998901, -0.9461190104484558, 0.045820269733667374, 0.020169518887996674, -0.07856457680463791, 0.1965046525001526, -0.06543214619159698, 0.21221867203712463, 0.013171808794140816, 0.04333380609750748, -0.12466897815465927, 0.06612717360258102, -0.08336719125509262, -0.18692001700401306, 0.1468142569065094, -0.03565426543354988, 0.09768509119749069, 0.01434645988047123, 0.11569683253765106, 0.2393883913755417},
# {0.19759058952331543, 0.3186633586883545, 0.19753043353557587, -0.07341809570789337, -0.303108274936676, -0.0517427995800972, 0.1478356271982193, 0.807962954044342, 0.34763821959495544, -0.03707985579967499, 0.1488901823759079, 0.10604148358106613, -0.07165392488241196, -0.036821167916059494, -0.5240841507911682, 0.15419524908065796, 0.26740068197250366, 0.17564430832862854, 0.19151557981967926, 0.15439116954803467, 0.1569051891565323, 0.17751887440681458, 0.11133921146392822, 0.1636640578508377, -0.022783592343330383, 0.12944793701171875, 0.14889337122440338, -0.05428735539317131, 0.25424620509147644, 0.11292167752981186, -0.15091419219970703, 0.027737172320485115, -0.18722666800022125, 0.0659586638212204, -0.14651891589164734, 0.1639341413974762},
# {-0.3456709682941437, 0.17907294631004333, -0.2311396449804306, -0.20232711732387543, 0.5845279097557068, -0.049527574330568314, -0.2129231095314026, 0.9987307190895081, 0.21964852511882782, -0.833698034286499, 0.15787653625011444, -0.7535766959190369, 0.3378733694553375, 0.18550965189933777, 0.16120629012584686, 0.17519667744636536, 0.6369571089744568, 0.3699948191642761, 0.038584209978580475, -0.0852404534816742, 0.3205137550830841, -0.04208546131849289, -0.16026771068572998, -0.10339129716157913, -0.012271149083971977, 0.021959014236927032, 0.14316852390766144, -0.01631728559732437, -0.1885109692811966, -0.2035307139158249, 0.1264493316411972, -0.10214827209711075, 0.06329835951328278, -0.11321565508842468, -0.09189987182617188, -0.20187422633171082},
# {-0.30296236276626587, 0.5479893684387207, 0.109149269759655, -0.39400333166122437, 0.6962034702301025, 0.05621445178985596, -0.0568670816719532, 1.2456423044204712, 0.4467504024505615, -0.4849650263786316, 0.7577177882194519, -0.12348116934299469, 0.39823946356773376, -0.48607945442199707, 0.2110876590013504, 0.760816752910614, 1.2142009735107422, 0.8587434887886047, -0.09707115590572357, -0.08800327777862549, 0.11031898111104965, -0.0782221257686615, -0.06093961372971535, 0.04404602199792862, 0.12837843596935272, -0.06020359694957733, -0.05376825109124184, -0.0653076246380806, -0.08153422921895981, 0.21715085208415985, 0.11896543204784393, 0.04755961149930954, -0.18390192091464996, -0.16145379841327667, -0.10632365942001343, 0.03867842257022858},
# {0.08239506930112839, -0.05386100336909294, -0.32520726323127747, 0.004402208607643843, -0.26597854495048523, -0.23110827803611755, -0.5794411897659302, 0.7314938902854919, -0.12810149788856506, -0.7291152477264404, -0.4092084467411041, -0.6481623649597168, -0.6231080889701843, -0.01639162003993988, 0.19958317279815674, -0.22148506343364716, -0.48993414640426636, -0.3473946154117584, 0.04467390477657318, 0.17878784239292145, 0.32351648807525635, 0.02652297355234623, 0.07749922573566437, -0.0569564588367939, 0.22041361033916473, 0.021376946941018105, 0.273802787065506, -0.1005072370171547, -0.2508991062641144, 0.018167978152632713, -0.13175252079963684, 0.1848730742931366, -0.27240970730781555, 0.013126568868756294, 0.04516956955194473, 0.03470545634627342}};

# %%
print("const float l2_weights[NUM_CLASSES][HIDDEN_SIZE] = {", end='')
weights = ''
for row in l2_weight:
    weights += '{'
    for cell in row:
        weights += str(cell) + ', '
    weights = weights[:-2] + '},\n'
weights = weights[:-2] + '};'
print(weights)
# Out:
# const float l2_weights[NUM_CLASSES][HIDDEN_SIZE] = {{-0.09548430144786835, -0.03395885229110718, -0.09811938554048538, -0.04564622789621353, 0.028937123715877533, -0.16248704493045807, 0.10498672723770142, -0.16764508187770844, 0.28133320808410645, 0.140278160572052, -0.10908842086791992, 0.3037027418613434, 0.04044416919350624, 0.06996949017047882, -0.198881134390831, -0.2094779759645462, -0.014100474305450916, 0.6162449717521667, 0.0985562652349472, 0.423587441444397},
# {0.12505847215652466, -0.17951709032058716, 0.09106337279081345, 0.1357848346233368, 0.20477169752120972, 0.12727369368076324, 0.19728487730026245, 0.2695009708404541, -0.7718627452850342, 0.14876717329025269, -0.32329100370407104, -0.2513580620288849, 0.16203387081623077, -0.22017818689346313, 0.06506700813770294, 0.1581232100725174, -0.05689410865306854, -0.20234188437461853, 0.027573073282837868, -0.16650605201721191},
# {0.11324868351221085, -0.07964815199375153, -0.017609208822250366, -0.26008614897727966, -0.18499313294887543, 0.1893758475780487, 0.1883293092250824, 0.10996107757091522, 0.017950549721717834, 0.0553695373237133, -0.30189839005470276, -0.09958115965127945, 0.05793873220682144, 0.3268749713897705, 0.18125474452972412, 0.02101163938641548, -0.044733867049217224, -0.10770676285028458, 0.04849132522940636, 0.06342736631631851},
# {0.02125907689332962, 0.05139480158686638, 0.24217882752418518, -0.02084539271891117, 0.17394503951072693, -0.08294820040464401, 0.10662615299224854, 0.3036326467990875, 0.0226886048913002, 0.07001988589763641, -0.1543138325214386, -0.17234578728675842, -0.12320946902036667, -0.06800590455532074, -0.09083324670791626, -0.12371057271957397, 0.16017654538154602, 0.012675830163061619, 0.21637389063835144, -0.16411630809307098},
# {-0.1146564707159996, -0.036352451890707016, 0.19069266319274902, 0.10828343033790588, -0.13954338431358337, 0.07729952782392502, 0.22011810541152954, -0.5177943706512451, 0.0069655124098062515, -0.1392393857240677, 0.4041307270526886, 0.043129146099090576, 0.15056827664375305, 0.002062372164800763, 0.09157482534646988, 0.19443169236183167, -0.4868767559528351, -0.6533823609352112, -0.08501394093036652, -0.2579599916934967}};

# %% [markdown]
# ## Get test data for software-hardware comparison

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import preprocessing

# %%
DATA_DIR = 'data'
RAW = DATA_DIR + '/raw'
NUM_FEATURES = 36

# %%
test_df = pd.read_csv(f'{DATA_DIR}/test.csv')
X_test = test_df.drop('action', axis='columns')
y_test = test_df['action']

# %%
data = [torch.Tensor(X_test.iloc[x].astype(float)) for x in range(5)]

# %%
data
# Out:
# [tensor([ 3.1000e-01, -1.0800e+00, -7.1600e-02,  2.5055e-01,  2.2250e-01,
#           1.8464e-01,  1.1500e+00, -7.5000e-01,  3.3620e-01,  4.5541e-01,
#           4.9750e-01,  3.6738e-01,  8.9000e-01, -1.5800e+00, -7.4200e-02,
#           6.3124e-01,  9.4500e-01,  5.4274e-01,  1.6082e+02, -2.5134e+02,
#          -7.1260e+00,  8.0422e+01,  4.4533e+01,  5.0580e+01,  2.6117e+02,
#          -2.8273e+02, -2.4086e+00,  1.2021e+02,  5.4765e+01,  7.7564e+01,
#           2.7862e+02, -2.6073e+02, -9.0498e+00,  9.0063e+01,  4.3487e+01,
#           5.4934e+01]),
#  tensor([ 1.4800e+00, -6.9000e-01, -1.7820e-01,  4.0969e-01,  2.2000e-01,
#           2.5765e-01,  1.8300e+00, -1.1100e+00,  1.2720e-01,  6.1517e-01,
#           4.8250e-01,  4.5133e-01,  1.2800e+00, -1.2700e+00, -1.9820e-01,
#           4.3570e-01,  4.1750e-01,  3.1715e-01,  1.6864e+02, -3.1762e+02,
#          -3.6890e+01,  1.1007e+02,  1.2509e+02,  8.5393e+01,  2.3456e+02,
#          -2.8976e+02, -3.4642e+01,  9.6951e+01,  6.0792e+01,  6.3434e+01,
#           1.6513e+02, -2.7067e+02, -3.2617e+01,  8.7604e+01,  7.5137e+01,
#           6.2304e+01]),
#  tensor([ 1.5900e+00, -1.0400e+00, -8.0000e-02,  4.9164e-01,  1.9500e-01,
#           2.9360e-01,  2.2400e+00, -6.1000e-01,  4.0160e-01,  7.0727e-01,
#           1.8750e-01,  5.4403e-01,  7.3000e-01, -4.4000e-01,  2.5000e-02,
#           2.2853e-01,  1.4500e-01,  1.6160e-01,  2.1367e+02, -3.1610e+02,
#          -7.0160e-01,  9.6777e+01,  3.8908e+01,  5.8860e+01,  2.2659e+02,
#          -2.7257e+02,  1.1261e+01,  8.2580e+01,  4.3353e+01,  5.3361e+01,
#           2.8158e+02, -2.6199e+02, -3.2884e+00,  1.3428e+02,  2.4070e+01,
#           8.7553e+01]),
#  tensor([ 6.9000e-01, -8.2000e-01, -1.4900e-01,  2.5673e-01,  1.4750e-01,
#           1.7588e-01,  2.1800e+00, -7.3000e-01,  3.3420e-01,  7.3279e-01,
#           1.0250e-01,  5.3752e-01,  9.0000e-01, -5.0000e-01, -5.0000e-02,
#           2.8340e-01,  9.5000e-02,  1.8920e-01,  2.2424e+02, -3.1334e+02,
#          -1.2337e+01,  1.2314e+02,  2.2690e+01,  7.9391e+01,  2.7542e+02,
#          -2.6735e+02,  7.3566e+00,  1.1249e+02,  2.2642e+01,  6.9174e+01,
#           2.0990e+02, -1.9880e+02, -1.3646e+01,  7.0755e+01,  1.5392e+01,
#           4.4546e+01]),
#  tensor([ 1.0600e+00,  2.0000e-01,  4.6180e-01,  1.8276e-01,  1.2000e-01,
#           1.3372e-01,  1.5400e+00,  1.8000e-01,  4.3680e-01,  3.2788e-01,
#           2.7000e-01,  2.4379e-01, -4.2000e-01, -1.9400e+00, -1.0162e+00,
#           2.9101e-01,  2.5000e-01,  2.2378e-01,  1.9843e+02, -1.5553e+02,
#           1.8664e+00,  7.1226e+01,  2.7157e+01,  4.3560e+01,  2.1672e+02,
#          -1.7907e+02,  5.4784e+00,  6.5343e+01,  2.8480e+01,  4.2546e+01,
#           1.2965e+02, -7.9890e+01, -5.5538e+00,  3.7842e+01,  2.7475e+01,
#           2.5752e+01])]

# %%
with torch.no_grad():
    for d in data:
        start_time = time.time()
        output = model(d)
        action = np.argmax(output)
#         print(f"Inference time: {time.time() - start_time}")    
        print(action)
# Out:
# tensor(3)
# tensor(4)
# tensor(1)
# tensor(1)
# tensor(4)

# %%
for x in range(5):
    print(y_test[x])
# Out:
# 3
# 4
# 1
# 1
# 3

# %% [markdown]
# ## Compare software-hardware running time and accuracy

# %%
# 1 sample

with torch.no_grad():
    start_time = time.time()

    data = torch.Tensor(X_test.iloc[0].astype(float))
    output = model(data)
    action = np.argmax(output)

    end_time = time.time()
    print(f"Prediction: {action}; Ground truth value: {y_test[0]}")
    print(f"Inference time: {((end_time - start_time) * 1000):.4f} ms")
# Out:
# Prediction: 3; Ground truth value: 3
# Inference time: 0.5820 ms

# %%
# whole test set (or dev + test set used in training)

with torch.no_grad():
    start_time = time.time()
    
    num_correct = 0
    num_samples = 0

    for i in range(len(X_test[:])):
        data = torch.Tensor(X_test.iloc[i].astype(float))
        output = model(data)
        action = np.argmax(output)
        num_samples += 1
        num_correct += (action == y_test[i])

    end_time = time.time()
    print(f"Accuracy: {(100.0 * num_correct / num_samples):.2f}%")
    print(f"Inference time: {(end_time - start_time):.4f} s")
# Out:
# Accuracy: 91.96%
# Inference time: 0.0685 s

# %%
len(X_test)
# Out:
# 112
