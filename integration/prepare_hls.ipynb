# %%
import torch
import torch.nn as nn
import time
import os

# %% [markdown]
# ## Load model

# %%
class FCN(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(FCN, self).__init__()
        self.input_size = input_size
        self.l1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.l2 = nn.Linear(hidden_size, num_classes)
    
    def forward(self, x):
        out = self.l1(x)
        out = self.relu(out)
        out = self.l2(out) 
        return out

# %%
model = FCN(1,1,1)
model = torch.load('model.pth')
model
# Out:
# FCN(
#   (l1): Linear(in_features=36, out_features=20, bias=True)
#   (relu): ReLU()
#   (l2): Linear(in_features=20, out_features=4, bias=True)
# )

# %%
for weight in model.state_dict():
    print(weight)
# Out:
# l1.weight
# l1.bias
# l2.weight
# l2.bias

# %%
for key, val in model.state_dict().items():
    print(key, val.shape)
# Out:
# l1.weight torch.Size([20, 36])
# l1.bias torch.Size([20])
# l2.weight torch.Size([4, 20])
# l2.bias torch.Size([4])

# %% [markdown]
# ## Print weights for HLS

# %%
l1_weight = model.state_dict()['l1.weight'].tolist()
l2_weight = model.state_dict()['l2.weight'].tolist()
l1_bias = model.state_dict()['l1.bias'].tolist()
l2_bias = model.state_dict()['l2.bias'].tolist()

# %%
print("const float l1_bias[HIDDEN_SIZE] = {", end='')
biases = ''
for b in l1_bias:
    biases += str(b) + ', '
biases = biases[:-2] + '};'
print(biases)
# Out:
# const float l1_bias[HIDDEN_SIZE] = {-0.05334458872675896, -0.13644450902938843, -0.2673816680908203, 0.12261010706424713, -0.17974506318569183, -0.008566997945308685, 0.1170906275510788, 0.005460590589791536, -0.14909523725509644, 0.16343431174755096, 0.3446892201900482, -0.08835111558437347, -0.019531795755028725, 0.025058090686798096, 0.5078228712081909, 0.06073518097400665, 0.04052054509520531, -0.17416788637638092, 0.0005443513509817421, -0.1994025558233261};

# %%
print("const float l2_bias[NUM_CLASSES] = {", end='')
biases = ''
for b in l2_bias:
    biases += str(b) + ', '
biases = biases[:-2] + '};'
print(biases)
# Out:
# const float l2_bias[NUM_CLASSES] = {0.011831509880721569, -0.2243700921535492, 0.0035149359609931707, 0.4138830602169037};

# %%
print("const float l1_weights[HIDDEN_SIZE][INPUT_SIZE] = {", end='')
weights = ''
for row in l1_weight:
    weights += '{'
    for cell in row:
        weights += str(cell) + ', '
    weights = weights[:-2] + '},\n'
weights = weights[:-2] + '};'
print(weights)
# Out:
# const float l1_weights[HIDDEN_SIZE][INPUT_SIZE] = {{-0.06309240311384201, -0.2532886862754822, 1.0538132190704346, 0.21994014084339142, 0.003935294225811958, 0.38774168491363525, -0.5814903378486633, 0.17311634123325348, -0.3715142011642456, -0.7375488877296448, -0.455607533454895, -0.8833975791931152, 0.8786311149597168, -0.9904577136039734, 0.30869221687316895, 0.9575240612030029, 0.8208673596382141, 0.8438540101051331, 0.008634628728032112, -0.11326632648706436, -0.1425938457250595, 0.047284919768571854, 0.2720261216163635, 0.16587021946907043, 0.0936233252286911, 0.09328111261129379, -0.13498376309871674, -0.1771565079689026, -0.0023882025852799416, 0.20226018130779266, 0.026079652830958366, 0.11071846634149551, 0.0380258709192276, -0.20030444860458374, -0.07657022029161453, -0.2014259248971939},
# {-0.10682124644517899, 0.03815050795674324, -0.12337307631969452, -0.050704747438430786, -0.13342903554439545, 0.0677933394908905, -0.17710669338703156, 0.11545603722333908, -0.2188645303249359, -0.07339926064014435, -0.030111435800790787, -0.17658871412277222, -0.11714551597833633, 0.02036275342106819, 0.023868553340435028, 0.02073713392019272, -0.0703204795718193, -0.08104699850082397, -0.14648857712745667, -0.03019804134964943, 0.12477525323629379, -0.18448802828788757, 0.02574952505528927, -0.20426727831363678, -0.06789029389619827, 0.035291947424411774, 0.15935611724853516, 0.03586148843169212, -0.07472023367881775, -0.19743098318576813, -0.16389788687229156, 0.009848309680819511, -0.060677822679281235, -0.23640285432338715, -0.06792926043272018, 0.01616808958351612},
# {-0.1838986575603485, -0.7179715037345886, -1.3913097381591797, 0.6010375618934631, -0.5439773797988892, 0.4900588393211365, -0.5315439105033875, 0.013076337985694408, -0.8876684308052063, -0.9532776474952698, -1.0310935974121094, -0.9244442582130432, 1.5895940065383911, -0.2912222445011139, 1.3574994802474976, 0.8521608710289001, 0.09694135189056396, 0.4434429109096527, -0.03880453109741211, -0.13416193425655365, -0.1854706108570099, 0.11654539406299591, -0.04991670697927475, 0.27605530619621277, -0.004186647478491068, 0.006821636576205492, 0.21237577497959137, 0.015835709869861603, -0.004709716886281967, -0.08336394280195236, -0.012399029918015003, 0.1217619851231575, 0.03255394846200943, 0.07082650065422058, 0.14235557615756989, 0.2272869348526001},
# {0.14528895914554596, -0.11914368718862534, -0.14251872897148132, -0.11858974397182465, 0.02833537757396698, -0.027684509754180908, 0.15513794124126434, 0.1368989795446396, 0.02341298758983612, -0.0847351998090744, 0.026471197605133057, -0.14143556356430054, -0.14834538102149963, 0.16531892120838165, 0.09791983664035797, -0.16399137675762177, -0.0956304669380188, 0.072877898812294, -0.047262370586395264, 0.08896879851818085, -0.003236129879951477, 0.04847650229930878, -0.07688619941473007, -0.01910555362701416, -0.0685802698135376, 0.1452634185552597, -0.13581357896327972, 0.08911938965320587, 0.14497138559818268, -0.07118098437786102, -0.0708228349685669, 0.02468322217464447, -0.07530581951141357, -0.08977639675140381, 0.0475376695394516, -0.054272137582302094},
# {0.12880633771419525, -0.10508563369512558, 0.2103583663702011, -0.07074818015098572, 0.13542485237121582, 0.1404067426919937, 0.08744297176599503, -0.05468763783574104, 0.13182106614112854, -0.17868103086948395, -0.04889910668134689, 0.07856078445911407, -0.16147863864898682, 0.08231751620769501, 0.026113910600543022, 0.1621887981891632, 0.15346531569957733, 0.19414350390434265, -0.06804816424846649, 0.056352369487285614, 0.06870931386947632, -0.020822957158088684, -0.07282379269599915, 0.06343935430049896, -0.011267205700278282, -0.009930175729095936, -0.11030574142932892, -0.12731443345546722, -0.1273062378168106, 0.0832800641655922, 0.11177287995815277, 0.14080466330051422, -0.34082671999931335, 0.04073762893676758, 0.05650557577610016, 0.07559052854776382},
# {-0.25755900144577026, 0.21015553176403046, 0.0016740001738071442, -0.16383779048919678, 0.05158583074808121, -0.07652314007282257, 0.05787331983447075, 0.00672603165730834, -0.24448806047439575, -0.15138374269008636, -0.034236155450344086, -0.07947678864002228, 0.030389059334993362, 0.15646228194236755, -0.04670194536447525, 0.00958250556141138, -0.12518537044525146, -0.22295399010181427, -0.19398567080497742, -0.04382675886154175, 0.04223226010799408, -0.032669201493263245, -0.08313539624214172, -0.10515256971120834, -0.16985566914081573, -0.015757262706756592, -0.049430932849645615, -0.023663034662604332, 0.05396623909473419, -0.24753925204277039, -0.22297149896621704, 0.059852614998817444, 0.08521151542663574, -0.039938781410455704, 0.057509589940309525, -0.07354533672332764},
# {-0.1585405170917511, -0.10899480432271957, -0.019948795437812805, -0.11502417176961899, 0.12419082224369049, -0.06871943175792694, -0.11465370655059814, 0.164418026804924, -0.05984662473201752, 0.16100727021694183, 0.11063648760318756, -0.14195597171783447, -0.07499011605978012, -0.06880830228328705, 0.1504497081041336, -0.018213078379631042, -0.08354543149471283, 0.02080117166042328, 0.06566046178340912, 0.1605234295129776, 0.008532032370567322, -0.1380845159292221, 0.04617573320865631, -0.06210814416408539, -0.020197078585624695, 0.05473552644252777, -0.01818138360977173, -0.045967504382133484, 0.15154235064983368, 0.056993767619132996, -0.02337755262851715, 0.083240807056427, -0.09280721843242645, 0.13433296978473663, -0.0030661672353744507, 0.16612423956394196},
# {0.017148589715361595, -0.10630538314580917, -0.00014993594959378242, 0.03787844628095627, -0.18587806820869446, 0.04602932184934616, -0.041212014853954315, 0.15845952928066254, 0.08604922890663147, -0.06068390607833862, -0.08862639963626862, -0.0019398221047595143, -0.10955468565225601, 0.09335825592279434, 0.061644747853279114, -0.018878629431128502, -0.08723191171884537, 0.0030688445549458265, 0.0850425586104393, 0.07467219978570938, 0.05357646942138672, -0.049458399415016174, -0.03561155125498772, -0.014971013180911541, -0.12233252823352814, -0.019604787230491638, -0.054765235632658005, -0.08209897577762604, 0.0013096281327307224, -0.07157007604837418, -0.1848367154598236, 0.09697970747947693, -0.19787415862083435, -0.16233164072036743, -0.20732508599758148, -0.04905392974615097},
# {0.34616589546203613, 0.15497635304927826, 2.4974138736724854, 0.3219923973083496, 0.6606050729751587, 0.2435062974691391, -0.8766719698905945, 0.4226832687854767, -0.160511776804924, -1.095494031906128, -0.15134979784488678, -0.7646944522857666, 0.6031598448753357, -1.8875627517700195, -1.2554939985275269, 1.6727244853973389, 2.019947052001953, 1.7115181684494019, -0.029572010040283203, -0.01864630915224552, -0.22704775631427765, -0.4093610346317291, 0.13761743903160095, -0.1583770513534546, -0.014365876093506813, -0.02590647153556347, -0.29074183106422424, 0.09147021919488907, 0.11137713491916656, 0.01174205169081688, 0.2624252140522003, -0.10394533723592758, -0.7844906449317932, -0.35627344250679016, 0.06356215476989746, -0.41934701800346375},
# {-0.013906121253967285, 0.11473892629146576, 0.11713238060474396, -0.02259303629398346, 0.13698090612888336, -0.13654577732086182, -0.0897739976644516, -0.08136016130447388, -0.11121182143688202, -0.1282031536102295, 0.07970128953456879, -0.11028057336807251, 0.1055494099855423, 0.052139997482299805, 0.007373929023742676, 0.04898454248905182, 0.11438368260860443, 0.06798012554645538, 0.020464733242988586, 0.057920292019844055, 0.09088392555713654, -0.04793928563594818, -0.06552978605031967, 0.14939816296100616, 0.01097552478313446, 0.11433784663677216, 0.14274846017360687, -0.033271610736846924, 0.07609312236309052, 0.1458006054162979, -0.11771126836538315, 0.058373257517814636, 0.07976149022579193, 0.08715926110744476, -0.007581546902656555, -0.15159229934215546},
# {-0.16282160580158234, 0.4299983084201813, 0.15802428126335144, -0.3743628263473511, 0.2117120772600174, -0.19341526925563812, 0.2189779430627823, -0.0036776657216250896, 0.06713879853487015, 0.04987987130880356, 0.42977750301361084, 0.06273391097784042, -0.8484167456626892, 0.0063371858559548855, -1.4348653554916382, -0.3286886513233185, 0.4102882146835327, -0.15917764604091644, 0.016524862498044968, -0.17437545955181122, -0.03336331993341446, -0.20503301918506622, -0.07459692656993866, -0.10816777497529984, -0.00848375167697668, -0.2492842674255371, 0.1453007459640503, 0.16231252253055573, 0.007041837088763714, -0.09586802870035172, -0.11620522290468216, 0.038573142141103745, 0.3157704174518585, -0.28905296325683594, -0.27150267362594604, -0.2121230810880661},
# {-0.05499274656176567, 0.6195688247680664, 0.383999228477478, -0.33826690912246704, 0.4918486177921295, -0.5732255578041077, 1.0011690855026245, -0.3291378319263458, 0.9133546352386475, 1.199739933013916, 1.113105297088623, 1.2776236534118652, -1.5287871360778809, 0.9232956767082214, -1.313063383102417, -1.2332814931869507, -0.9349735379219055, -1.086174488067627, 0.1929066777229309, 0.05248243734240532, 0.22437603771686554, -0.10126333683729172, -0.18367625772953033, -0.09436304122209549, -0.2541927397251129, -0.07096221297979355, -0.5995067954063416, -0.22764241695404053, -0.25139516592025757, 0.027054261416196823, 0.09737186878919601, -0.2509913444519043, 0.5097287893295288, 0.1425347626209259, 0.18672578036785126, 0.015332783572375774},
# {0.10216683894395828, -0.0546703115105629, -0.05488532781600952, -0.13374057412147522, 0.07851667702198029, -0.00023450078151654452, -0.09282136708498001, -0.13788668811321259, -0.1018534004688263, -0.03718036040663719, 0.041441336274147034, -0.1016659140586853, 0.016023937612771988, 0.051776982843875885, 0.1956295520067215, 0.012547122314572334, 0.06232361122965813, -0.12788476049900055, -0.10994906723499298, 0.08649570494890213, 0.04995066672563553, -0.015913330018520355, -0.011972651816904545, 0.11245331913232803, 0.011172543279826641, 0.0439731664955616, -0.00561224389821291, 0.11775923520326614, 0.07347952574491501, -0.1252785474061966, -0.143702432513237, 0.10734564810991287, -0.0298572089523077, -0.12879882752895355, -0.0712679922580719, 0.10757335275411606},
# {-0.14883378148078918, 0.0935889333486557, -0.08475150913000107, 0.11463655531406403, -0.06043803691864014, -0.0021602660417556763, 0.023258313536643982, 0.08245562016963959, -0.09855246543884277, -0.012309059500694275, 0.1579044610261917, 0.07971973717212677, -0.010547026991844177, -0.14359967410564423, -0.042681217193603516, 0.02328014373779297, -0.0856657475233078, -0.14832893013954163, -0.07884460687637329, -0.028501391410827637, 0.12748150527477264, -0.004755809903144836, -0.11729615926742554, -0.11240951716899872, -0.11505268514156342, -0.10179394483566284, -0.07659272849559784, -0.11480514705181122, 0.09242524206638336, -0.0767272338271141, -0.1424092948436737, 0.1259850412607193, -0.042363427579402924, -0.06859557330608368, 0.10196597874164581, -0.12620210647583008},
# {-0.17132030427455902, 0.5564583539962769, 0.2599681615829468, -0.34962040185928345, -0.07611442357301712, -0.12664268910884857, 0.1412714421749115, 0.013838031329214573, 0.14820799231529236, 0.2381272166967392, 0.017489925026893616, 0.1677442193031311, -0.6149014234542847, 0.45912349224090576, -0.5888586044311523, -0.6312181949615479, -0.06991608440876007, -0.4392726421356201, 0.1217186227440834, 0.10342174768447876, -0.0589103139936924, -0.20696401596069336, -0.02391117438673973, -0.08305958658456802, 0.2181958258152008, -0.1548653095960617, 0.15769228339195251, -0.055561553686857224, 0.08183460682630539, 0.028936492279171944, -0.04794073477387428, 0.04654916748404503, 0.37451159954071045, -0.2283087819814682, 0.15408754348754883, -0.26533639430999756},
# {0.1521400362253189, 0.10318808257579803, -0.026857376098632812, -0.12360501289367676, 0.04696017503738403, 0.04642559587955475, -0.04749952256679535, 0.006138071417808533, 0.16239400207996368, -0.07160179316997528, -0.10253874957561493, -0.0032955557107925415, -0.033194467425346375, 0.1656472235918045, 0.1553572565317154, -0.11427704989910126, 0.08072353899478912, 0.008473038673400879, 0.08648161590099335, 0.1345600038766861, 0.05559225380420685, -0.0007208138704299927, -0.13748657703399658, -0.15642017126083374, -0.12392644584178925, -0.010811403393745422, -0.1212560385465622, 0.061010316014289856, 0.05668933689594269, 6.656348705291748e-05, -0.11310172080993652, 0.10837461054325104, -0.03188256919384003, -0.04502328485250473, 0.10502748191356659, 0.16271261870861053},
# {-0.23908786475658417, 0.7724445462226868, 1.4384310245513916, -0.4589995741844177, 0.8108920454978943, -0.3002803325653076, 0.15815609693527222, 0.34592878818511963, 0.7351354956626892, 0.5885461568832397, 1.646915078163147, 0.8800562620162964, -1.6718724966049194, -0.3456116318702698, -3.4122188091278076, -0.015565376728773117, 1.537279725074768, 0.5444448590278625, -0.13331392407417297, -0.0953369066119194, -0.11441224813461304, -0.3328436613082886, 0.001501909806393087, -0.28917425870895386, -0.04508857801556587, -0.1317494809627533, 0.27638256549835205, -0.018710952252149582, 0.014980882406234741, -0.007912865839898586, 0.01413292158395052, -0.31012776494026184, -0.40518298745155334, -0.14424432814121246, -0.461553156375885, -0.3340553045272827},
# {-0.18641121685504913, 0.666240394115448, -1.4519615173339844, -0.4615132808685303, -0.15194949507713318, -0.40686213970184326, 1.1559571027755737, 0.0628601610660553, 0.897811770439148, 1.4276760816574097, 1.024680256843567, 1.3182311058044434, -1.4978773593902588, 1.443666696548462, -1.1843218803405762, -1.6616976261138916, -1.4225653409957886, -1.596996784210205, 0.0741092637181282, 0.1609765887260437, 0.06482156366109848, 0.009018498472869396, -0.2665777802467346, -0.09387505799531937, -0.05207366496324539, -0.10857106745243073, 0.01602880284190178, -0.12816496193408966, -0.15962302684783936, -0.28616905212402344, 0.03790729492902756, -0.19503504037857056, -0.10917522758245468, 0.061780743300914764, 0.22446836531162262, 0.42121565341949463},
# {0.006508191116154194, 0.13901790976524353, 0.024926695972681046, -0.09909691661596298, -0.027548326179385185, -0.06510220468044281, -0.23683108389377594, 0.20485560595989227, -0.11534401774406433, -0.13062280416488647, -0.013122259639203548, -0.18459945917129517, -0.01738806627690792, 0.03441426157951355, 0.13660486042499542, 0.08475223928689957, -0.07636574655771255, -0.15907657146453857, -0.0682884007692337, -0.08453535288572311, -0.051344119012355804, -0.14791451394557953, -0.04723895341157913, 0.09315620362758636, 0.08461203426122665, 0.18508704006671906, 0.14435704052448273, 0.07179199904203415, 0.037860020995140076, -0.17879994213581085, 0.08774557709693909, 0.22759374976158142, 0.09520025551319122, -0.09947321563959122, -0.20642900466918945, -0.23938952386379242},
# {0.0170661099255085, 0.1976795345544815, -0.10854201018810272, -0.1996207982301712, 0.06675209105014801, 0.04304942116141319, -0.10102080553770065, 0.07238943874835968, -0.008852140977978706, 0.08127614855766296, -0.1787554919719696, 0.061600878834724426, -0.22396963834762573, 0.019055884331464767, -0.21768741309642792, 0.036545731127262115, 0.1005701944231987, -0.08597390353679657, 0.05313685163855553, 0.11783597618341446, 0.2041689157485962, 0.009822475723922253, -0.019580228254199028, 0.06465919315814972, 0.00812961719930172, 0.16709834337234497, -0.12075868993997574, -0.0435897633433342, -0.019718240946531296, -0.07097513973712921, -0.15007610619068146, 0.10288149118423462, -0.13292206823825836, -0.16886816918849945, 0.036757856607437134, -0.025913072749972343}};

# %%
print("const float l2_weights[NUM_CLASSES][HIDDEN_SIZE] = {", end='')
weights = ''
for row in l2_weight:
    weights += '{'
    for cell in row:
        weights += str(cell) + ', '
    weights = weights[:-2] + '},\n'
weights = weights[:-2] + '};'
print(weights)
# Out:
# const float l2_weights[NUM_CLASSES][HIDDEN_SIZE] = {{-0.1280953586101532, -0.12167757004499435, 0.010786538943648338, -0.18267615139484406, -0.14638663828372955, 0.17025969922542572, 0.047933101654052734, -0.09269899129867554, -0.35289397835731506, -0.21688753366470337, -0.13649290800094604, 0.04241060093045235, 0.07317662984132767, 0.10657131671905518, -0.09870198369026184, 0.1900177299976349, 0.22705604135990143, 0.23391780257225037, -0.12960085272789001, -0.054554954171180725},
# {0.11042877286672592, 0.0495004840195179, 0.1541384905576706, 0.1309833526611328, 0.10469444841146469, 0.02568761073052883, -0.16886113584041595, -0.02422128990292549, 0.1624232679605484, -0.01301911473274231, -0.28847455978393555, -0.1841299831867218, -0.10822442173957825, 0.2215580940246582, -0.2397242784500122, -0.15751749277114868, 0.04291843622922897, 0.0031323463190346956, 0.04515921324491501, -0.09335663914680481},
# {0.06692615896463394, -0.032778121531009674, -0.19652682542800903, -0.11436666548252106, 0.1934041976928711, -0.036795809864997864, 0.0603615939617157, -0.15394195914268494, 0.3206373155117035, -0.16918355226516724, -0.015553890727460384, 0.033576060086488724, 0.01401862408965826, -0.22170808911323547, -0.05088203772902489, 0.07697784900665283, 0.2927704155445099, 0.019437624141573906, -0.012142457067966461, 0.2128022313117981},
# {0.12559349834918976, 0.18781661987304688, -0.15223903954029083, 0.08229586482048035, 0.039952315390110016, -0.0367860421538353, 0.19694414734840393, -0.15962354838848114, -0.06501662731170654, -0.09145593643188477, 0.0847562849521637, -0.12180101871490479, 0.04860419034957886, 0.19223159551620483, 0.200468510389328, 0.011093586683273315, -0.02012443169951439, -0.12937457859516144, 0.18858732283115387, 0.01933389902114868}};

# %% [markdown]
# ## Get test data for software-hardware comparison

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import preprocessing

# %%
DATA_DIR = 'data'
RAW = DATA_DIR + '/raw'
NUM_FEATURES = 36

# %%
test_df = pd.read_csv(f'{DATA_DIR}/test.csv')
X_test = test_df.drop('action', axis='columns')
y_test = test_df['action']

# %%
data = torch.Tensor(X_test.iloc[0].astype(float))

# %%
data
# Out:
# tensor([ 4.4000e-01, -9.3000e-01, -2.0600e-02,  2.4825e-01,  1.1750e-01,
#          1.6324e-01,  2.3500e+00, -1.0500e+00,  4.6900e-01,  6.2036e-01,
#          8.0750e-01,  5.0636e-01,  4.6000e-01, -2.0700e+00, -4.0840e-01,
#          6.2564e-01,  7.9250e-01,  5.1262e-01,  1.8701e+02, -3.1759e+02,
#         -1.2022e+01,  7.1242e+01,  1.1445e+01,  3.9310e+01,  2.7191e+02,
#         -2.7341e+02,  1.3346e+00,  1.0965e+02,  2.3070e+01,  6.3755e+01,
#          2.0676e+02, -1.9849e+02, -2.3408e+00,  7.3921e+01,  9.9550e+00,
#          4.1250e+01])

# %%
with torch.no_grad():
    start_time = time.time()
    output = model(data)
    action = np.argmax(output)
    print(f"Inference time: {time.time() - start_time}")    
    print(action)
# Out:
# Inference time: 0.0133819580078125
# tensor(2)

# %%
y_test[0]
# Out:
# 2

# %% [markdown]
# ## Compare software-hardware running time and accuracy

# %%
# 1 sample

with torch.no_grad():
    start_time = time.time()

    data = torch.Tensor(X_test.iloc[0].astype(float))
    output = model(data)
    action = np.argmax(output)

    end_time = time.time()
    print(f"Prediction: {action}; Ground truth value: {y_test[0]}")
    print(f"Inference time: {((end_time - start_time) * 1000):.4f} ms")
# Out:
# Prediction: 2; Ground truth value: 2
# Inference time: 3.7529 ms

# %%
# whole test set (or dev + test set used in training)

with torch.no_grad():
    start_time = time.time()
    
    num_correct = 0
    num_samples = 0

    for i in range(len(X_test[:])):
        data = torch.Tensor(X_test.iloc[i].astype(float))
        output = model(data)
        action = np.argmax(output)
        num_samples += 1
        num_correct += (action == y_test[i])

    end_time = time.time()
    print(f"Accuracy: {(100.0 * num_correct / num_samples):.2f}%")
    print(f"Inference time: {(end_time - start_time):.4f} s")
# Out:
# Accuracy: 96.88%
# Inference time: 0.0195 s

# %%
len(X_test)
# Out:
# 32
