# %% [markdown]
# # MotionSense Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %%
DATA = 'archive'
SUBJECTS_INFO = f'{DATA}/data_subjects_info.csv'
DEVICE_DATA = f'{DATA}/A_DeviceMotion_data'

# %%
sorted(os.listdir(DEVICE_DATA), key=lambda x: int(x.split('_')[-1]))
# Out:
# ['dws_1',
#  'dws_2',
#  'ups_3',
#  'ups_4',
#  'sit_5',
#  'std_6',
#  'wlk_7',
#  'wlk_8',
#  'jog_9',
#  'dws_11',
#  'ups_12',
#  'sit_13',
#  'std_14',
#  'wlk_15',
#  'jog_16']

# %%
dws1_sub1 = pd.read_csv(f'{DEVICE_DATA}/dws_1/sub_1.csv', index_col=[0])
dws1_sub1
# Out:
#       attitude.roll  attitude.pitch  attitude.yaw  gravity.x  gravity.y  \
# 0          1.528132       -0.733896      0.696372   0.741895   0.669768
# 1          1.527992       -0.716987      0.677762   0.753099   0.657116
# 2          1.527765       -0.706999      0.670951   0.759611   0.649555
# 3          1.516768       -0.704678      0.675735   0.760709   0.647788
# 4          1.493941       -0.703918      0.672994   0.760062   0.647210
# ...             ...             ...           ...        ...        ...
# 1746       1.797120       -0.562324      2.445889   0.824443   0.533154
# 1747       1.814297       -0.569719      2.449655   0.817212   0.539396
# 1748       1.830821       -0.578367      2.447967   0.809207   0.546658
# 1749       1.849557       -0.586962      2.439458   0.800485   0.553834
# 1750       1.869375       -0.596783      2.433775   0.790551   0.561984
#
#       gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %%
dws1_sub1.hist(bins=50, figsize=(20,15))
plt.show()

# %%
ups_3_sub1 = pd.read_csv(f'{DEVICE_DATA}/ups_3/sub_1.csv', index_col=[0])
ups_3_sub1

ups_3_sub1.hist(bins=50, figsize=(20,15))
plt.show()
